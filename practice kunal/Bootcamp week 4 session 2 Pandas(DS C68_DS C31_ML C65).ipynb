# %%
# import pandas

# %%
import pandas as pd

# %%
nums = [6,8,2,1]

# %%
# series : pd.Series()

# %%
nums_series = pd.Series(nums)
nums_series
# Out:
# 0    6
# 1    8
# 2    2
# 3    1
# dtype: int64

# %%
type(nums_series)
# Out:
# pandas.core.series.Series

# %%
# mathematical operations

# %%
print("Max number is  : ", nums_series.max())
# Out:
# Max number is  :  8

# %%
print("Min number is  : ", nums_series.min())
# Out:
# Min number is  :  1

# %%
print("Average number is  : ", nums_series.mean())
# Out:
# Average number is  :  4.25

# %%
print("Standard dev number is  : ", nums_series.std())
# Out:
# Standard dev number is  :  3.304037933599835

# %%
print("Median  number is  : ", nums_series.median())
# Out:
# Median  number is  :  4.0

# %%
# combine two series

# %%
s1 = pd.Series([1,2],index = ['a','b'], name = 's1')
s2 = pd.Series([3,4],index = ['a','b'], name = 's2')

# %%
s1
# Out:
# a    1
# b    2
# Name: s1, dtype: int64

# %%
s2
# Out:
# a    3
# b    4
# Name: s2, dtype: int64

# %%
# concat = combining multiple series to form dataframe

# %%
# axis = 0 -- > row wise data
# axis = 1 -- > column wise data

# %%
new_df = pd.concat([s1,s2],axis = 1) # combining column wise (horizontally)
new_df
# Out:
#    s1  s2
# a   1   3
# b   2   4

# %%
type(new_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# load data

# %%
# pd.read_csv(path of file)

df = pd.read_csv("telecom_churn.csv")

# %%
# df.head() : which will display first five rows from data

df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
# df.head(n) : which will display first n rows from data

df.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
# df.tail() : which will display last five rows from data

df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
# df.tail(n) : which will display last n rows from data

df.tail(3)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# ...

# %%
# .shape : number of rows and columns

df.shape
# Out:
# (3333, 20)

# %%
# .size : number of data points present in data = rows*col

# %%
df.size
# Out:
# 66660

# %%
# .columns = gives a list of column names present in data
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['State',
#  'Account length',
#  'Area code',
#  'International plan',
#  'Voice mail plan',
#  'Number vmail messages',
#  'Total day minutes',
#  'Total day calls',
#  'Total day charge',
#  'Total eve minutes',
#  'Total eve calls',
#  'Total eve charge',
#  'Total night minutes',
#  'Total night calls',
#  'Total night charge',
#  'Total intl minutes',
#  'Total intl calls',
#  'Total intl charge',
#  'Customer service calls',
#  'Churn']

# %%
# .info = overall information regarding data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
# object in pandas  = string data type

# %%
df.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
# .describe() = statistical information related to data

df.describe() # by default gives information for numerical columns only
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
# 'O','Object'
df.describe(include='O')
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %%
# all
#df.describe(include='all')

# %%
# find null values 

df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
# value_counts = count of values present in particular column(categorical)

df['Churn'].value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
df['Area code'].value_counts()
# Out:
# 415    1655
# 510     840
# 408     838
# Name: Area code, dtype: int64

# %%
# normalize=True : convert values in range 0 to 1

df['Area code'].value_counts(normalize=True)*100
# Out:
# 415    49.654965
# 510    25.202520
# 408    25.142514
# Name: Area code, dtype: float64

# %%
df['Churn'].value_counts(normalize=True)*100
# Out:
# False    85.508551
# True     14.491449
# Name: Churn, dtype: float64

# %%
# python method
(df['Churn'].value_counts()/ df.shape[0])*100
# Out:
# False    85.508551
# True     14.491449
# Name: Churn, dtype: float64

# %%
# Accessing columns from data (single column)

# %%
# method1  : use [ ] brackets
df['Churn']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Name: Churn, Length: 3333, dtype: bool

# %%
# method 2 : use dot (.)
df.Churn
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Name: Churn, Length: 3333, dtype: bool

# %%
# problem with method 2

df.Number vmail messages
# Out:
#   File "<ipython-input-75-9e7b07fcbd3f>", line 3
#     df."Number vmail messages"
#        ^
# SyntaxError: invalid syntax

# %%
df["Number vmail messages"]
# Out:
# 0       25
# 1       26
# 2        0
# 3        0
# 4        0
#         ..
# 3328    36
# 3329     0
# 3330     0
# 3331     0
# 3332    25
# Name: Number vmail messages, Length: 3333, dtype: int64

# %%
df.head(3)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# ...

# %%
# subset of data from main data

# %%
df.iloc[2]  # [2] : index number
# Out:
# State                        NJ
# Account length              137
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         243.4
# Total day calls             114
# Total day charge          41.38
# Total eve minutes         121.2
# Total eve calls             110
# Total eve charge           10.3
# Total night minutes       162.6
# Total night calls           104
# Total night charge         7.32
# Total intl minutes         12.2
# Total intl calls              5
# Total intl charge          3.29
# Customer service calls        0
# Churn                     False
# Name: 2, dtype: object

# %%
# subset data using iloc : iloc[n1:n2, m1:m2]
# n1:n2 -- > rows  n1 = start, n2 = n2-1 (end)
# m1:m2 -- > columns  m1 = start, m2 = m2-1 (end)

# %%
df.iloc[3:8]
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 3                      0              299.4               71
# 4                      0              166.7              113
# 5                      0              223.4               98
# 6                     24              218.2               88
# 7                      0              157.0               79
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3             50.90               61.9               88              5.26
# ...

# %%
df.iloc[3:8,0:4]
# Out:
#   State  Account length  Area code International plan
# 3    OH              84        408                Yes
# 4    OK              75        415                Yes
# 5    AL             118        510                Yes
# 6    MA             121        510                 No
# 7    MO             147        415                Yes

# %%
df.iloc[:10,:3].describe()
# Out:
#        Account length   Area code
# count       10.000000   10.000000
# mean       117.500000  432.600000
# std         23.486403   40.893357
# min         75.000000  408.000000
# 25%        109.500000  415.000000
# 50%        119.500000  415.000000
# 75%        134.750000  415.000000
# max        147.000000  510.000000

# %%
df.iloc[3:8,0]
# Out:
# 3    OH
# 4    OK
# 5    AL
# 6    MA
# 7    MO
# Name: State, dtype: object

# %%
df.iloc[3:,2:8]
# Out:
#       Area code International plan Voice mail plan  Number vmail messages  \
# 3           408                Yes              No                      0
# 4           415                Yes              No                      0
# 5           510                Yes              No                      0
# 6           510                 No             Yes                     24
# 7           415                Yes              No                      0
# ...         ...                ...             ...                    ...
# 3328        415                 No             Yes                     36
# 3329        415                 No              No                      0
# 3330        510                 No              No                      0
# 3331        510                Yes              No                      0
# 3332        415                 No             Yes                     25
#
#       Total day minutes  Total day calls
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# subset data using loc : provide row index  and column names

df.loc[2:8, ['Total eve calls', 'Total eve charge', 'Total night minutes']]
# Out:
#    Total eve calls  Total eve charge  Total night minutes
# 2              110             10.30                162.6
# 3               88              5.26                196.9
# 4              122             12.61                186.9
# 5              101             18.75                203.9
# 6              108             29.62                212.6
# 7               94              8.76                211.8
# 8               80             29.89                215.8

# %%
# iloc : required column index
# loc : required column name

# %%
# create a subset from multiple columns  = [[ ]]

df[['Churn','Total eve calls', 'Total eve charge', 'Total night minutes']]
# Out:
#       Churn  Total eve calls  Total eve charge  Total night minutes
# 0     False               99             16.78                244.7
# 1     False              103             16.62                254.4
# 2     False              110             10.30                162.6
# 3     False               88              5.26                196.9
# 4     False              122             12.61                186.9
# ...     ...              ...               ...                  ...
# 3328  False              126             18.32                279.1
# 3329  False               55             13.04                191.3
# 3330  False               58             24.55                191.9
# 3331  False               84             13.57                139.2
# 3332  False               82             22.60                241.4
#
# [3333 rows x 4 columns]

# %%
df.head(3)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# ...

# %%
# sort_values : sort dataframe by column name

df.sort_values(by = 'State') # default method is ascending
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 181     AK             126        415                 No              No
# 550     AK             111        415                 No              No
# 2929    AK              71        510                 No              No
# 1260    AK              76        415                 No             Yes
# 1803    AK             101        510                 No              No
# ...    ...             ...        ...                ...             ...
# 3258    WY             148        408                 No              No
# 1265    WY              95        415                 No             Yes
# 762     WY             161        415                Yes              No
# 1628    WY             131        510                 No              No
# 609     WY             111        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.sort_values(by = 'State',ascending=False)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 273     WY             139        415                 No              No
# 731     WY              90        415                 No              No
# 2912    WY             151        415                 No              No
# 1628    WY             131        510                 No              No
# 2915    WY              58        510                 No              No
# ...    ...             ...        ...                ...             ...
# 1094    AK             115        415                 No              No
# 3283    AK              99        510                 No              No
# 1162    AK             173        510                 No              No
# 2752    AK              55        408                 No             Yes
# 2270    AK             146        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
 # to make permanant change -- > inplace = True

# %%
# create copy of data

df_copy = df.copy()

# %%
df_copy.sort_values(by = 'State',inplace = True)

# %%
df_copy
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 181     AK             126        415                 No              No
# 550     AK             111        415                 No              No
# 2929    AK              71        510                 No              No
# 1260    AK              76        415                 No             Yes
# 1803    AK             101        510                 No              No
# ...    ...             ...        ...                ...             ...
# 3258    WY             148        408                 No              No
# 1265    WY              95        415                 No             Yes
# 762     WY             161        415                Yes              No
# 1628    WY             131        510                 No              No
# 609     WY             111        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# reset_index() : reset the order of index

df_copy.reset_index(inplace = True)

# %%
df_copy
# Out:
#       index State  Account length  Area code International plan  \
# 0       181    AK             126        415                 No
# 1       550    AK             111        415                 No
# 2      2929    AK              71        510                 No
# 3      1260    AK              76        415                 No
# 4      1803    AK             101        510                 No
# ...     ...   ...             ...        ...                ...
# 3328   3258    WY             148        408                 No
# 3329   1265    WY              95        415                 No
# 3330    762    WY             161        415                Yes
# 3331   1628    WY             131        510                 No
# 3332    609    WY             111        415                 No
#
#      Voice mail plan  Number vmail messages  Total day minutes  \
# 0                 No                      0               58.2
# 1                 No                      0              172.8
# ...

# %%
# drop column : .drop()
df_copy.drop(['index'],inplace = True,axis = 1)

# %%
df_copy
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       AK             126        415                 No              No
# 1       AK             111        415                 No              No
# 2       AK              71        510                 No              No
# 3       AK              76        415                 No             Yes
# 4       AK             101        510                 No              No
# ...    ...             ...        ...                ...             ...
# 3328    WY             148        408                 No              No
# 3329    WY              95        415                 No             Yes
# 3330    WY             161        415                Yes              No
# 3331    WY             131        510                 No              No
# 3332    WY             111        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# sorting using multiple column

df.sort_values(by = ['State','Area code'])
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 36      AK              36        408                 No             Yes
# 95      AK             104        408                 No              No
# 339     AK              78        408                 No              No
# 684     AK             110        408                 No              No
# 718     AK             127        408                 No              No
# ...    ...             ...        ...                ...             ...
# 2670    WY             116        510                 No             Yes
# 2739    WY             101        510                 No             Yes
# 2874    WY             134        510                 No              No
# 2915    WY              58        510                 No              No
# 3172    WY              41        510                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# apply external function on data column

df['Area code new'] = df['Area code'].apply(lambda x : x+1000)

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# filtering data using single condition
df[df[column name] < condition > value]

# %%
df['Churn'].value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
df[df['Churn']==True]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 41      MD             135        408                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 3301    CA              84        415                 No              No
# 3304    IL              71        510                Yes              No
# 3320    GA             122        510                Yes              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# filter data using multiple columns

# %%
df[(df['Churn']==True) & (df['Area code']==415)]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 48      ID             119        415                 No              No
# 54      WY              87        415                 No              No
# 76      DC              82        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3265    ID              82        415                 No              No
# 3268    WA              84        415                 No              No
# 3287    KS             170        415                 No             Yes
# 3301    CA              84        415                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#df[(df['Churn']==True) & (df['Area code']==415)].loc[:,['Area code']].value_counts()

# %%
# crosstab : it gives calculations between two or more columns

# %%
pd.crosstab(df['Churn'],df['Area code'])
# Out:
# Area code  408   415  510
# Churn
# False      716  1419  715
# True       122   236  125

# %%
df[(df['Churn']==True) & (df['Area code']==510)]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 69      TX             150        510                 No              No
# 84      TX             106        510                 No              No
# 115     ME              36        510                Yes             Yes
# 127     MS              61        510                 No             Yes
# 197     TX             208        510                 No              No
# ...    ...             ...        ...                ...             ...
# 3255    RI             138        510                Yes              No
# 3272    MD             133        510                 No              No
# 3291    MI             119        510                Yes             Yes
# 3304    IL              71        510                Yes              No
# 3320    GA             122        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...
